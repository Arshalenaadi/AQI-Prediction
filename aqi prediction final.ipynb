# %%
#importing main packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv(r"C:\Users\Chinnu\Downloads\city_day.csv")

# %%
data.head()
# Out:
#      State       City station                  StationName  Status  \
# 0  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active
# 1  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active
# 2  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active
# 3  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active
# 4  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active
#
#          Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2      O3  \
# 0  01-01-2015    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64  133.36
# 1  02-01-2015    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55   34.06
# 2  03-01-2015    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07   30.70
# 3  04-01-2015    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59   36.08
# 4  05-01-2015    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33   39.31
#
#    Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0     0.00     0.02    0.00  NaN        NaN
# 1     3.68     5.50    3.77  NaN        NaN
# 2     6.80    16.40    2.25  NaN        NaN
# 3     4.43    10.14    1.00  NaN        NaN
# 4     7.01    18.89    2.78  NaN        NaN

# %%
data.shape
# Out:
# (29531, 20)

# %%
data.columns
# Out:
# Index(['State', 'City', 'station', 'StationName', 'Status', 'Date', 'PM2.5',
#        'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene',
#        'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Univariate and bivariate analysis using pair plotting
sns.pairplot(data)

# %%
#Converting dtype of date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['year'] = data['Date'].apply(lambda x:x.year)
data['month'] = data['Date'].apply(lambda x:x.month)
data['day'] = data['Date'].apply(lambda x:x.day)
data.head()
# Out:
#      State       City station                  StationName  Status       Date  \
# 0  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-01-01
# 1  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-02-01
# 2  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-03-01
# 3  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-04-01
# 4  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-05-01
#
#    PM2.5  PM10     NO    NO2  ...    SO2      O3  Benzene  Toluene  Xylene  \
# 0    NaN   NaN   0.92  18.22  ...  27.64  133.36     0.00     0.02    0.00
# 1    NaN   NaN   0.97  15.69  ...  24.55   34.06     3.68     5.50    3.77
# 2    NaN   NaN  17.40  19.30  ...  29.07   30.70     6.80    16.40    2.25
# 3    NaN   NaN   1.70  18.48  ...  18.59   36.08     4.43    10.14    1.00
# 4    NaN   NaN  22.10  21.42  ...  39.33   39.31     7.01    18.89    2.78
#
#    AQI  AQI_Bucket  year  month day
# 0  NaN         NaN  2015      1   1
# 1  NaN         NaN  2015      2   1
# 2  NaN         NaN  2015      3   1
# 3  NaN         NaN  2015      4   1
# 4  NaN         NaN  2015      5   1
#
# [5 rows x 23 columns]

# %%
sns.countplot(y=data.year)
plt.xticks(rotation=75);
plt.title('Yearly-No of Samples')
plt.ylabel(None);

# %%
#piechart on AQI_Bucket_distribution(2015-2020
AQI_Bucket_distribution =data.AQI_Bucket.value_counts()
plt.figure(figsize=(10,6))
plt.title('AQI_Bucket_distribution(2015-2020)')
plt.pie(AQI_Bucket_distribution, labels=AQI_Bucket_distribution.index, autopct='%1.1f%%', startangle=150);

# %%
# Air Quality - Yearly view
Yrs = ['year', 'AQI']
yr_df =data[Yrs].copy()
z = yr_df.groupby('year')['AQI'].mean()
Years = list(z.index)
Sum_of_AQI = z.tolist()
plt.figure(figsize=(12,6))
plt.title('Air Quality - Yearly view')
plt.plot(Years, Sum_of_AQI, color='red', marker='o')

# %%
#Distribustion of Elements which are impacting air quality
Elements = ['NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene','Xylene']
Elements_whichimpacting_airquality = data[Elements].copy()
element_df = Elements_whichimpacting_airquality.sum()
plt.figure(figsize=(12,6))
plt.title('Distribustion of Elements which are impacting air quality')
plt.pie(element_df, labels=element_df.index, autopct='%1.1f%%', startangle=180);
plt.legend()

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x = 'AQI', y = 'City', data = data)

plt.show()

# %% [markdown]
# # Finding Null Values

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.isna().sum()
# Out:
# State              0
# City               0
# station            0
# StationName        0
# Status           324
# Date               0
# PM2.5           4598
# PM10           11140
# NO              3582
# NO2             3585
# NOx             4185
# NH3            10328
# CO              2059
# SO2             3854
# O3              4022
# Benzene         5623
# Toluene         8041
# Xylene         18109
# AQI             4681
# AQI_Bucket      4681
# year               0
# month              0
# day                0
# dtype: int64

# %% [raw]
# % of null values in all features

# %%
null_values_percent=(data.isnull().sum()/data.shape[0]*100).sort_values(ascending=False)
null_values_percent
# Out:
# Xylene         61.322001
# PM10           37.723071
# NH3            34.973418
# Toluene        27.229014
# Benzene        19.041008
# AQI_Bucket     15.851139
# AQI            15.851139
# PM2.5          15.570079
# NOx            14.171549
# O3             13.619586
# SO2            13.050692
# NO2            12.139785
# NO             12.129626
# CO              6.972334
# Status          1.097152
# year            0.000000
# month           0.000000
# State           0.000000
# City            0.000000
# Date            0.000000
# StationName     0.000000
# station         0.000000
# day             0.000000
# dtype: float64

# %% [raw]
# missing_data_with_percentage=pd.concat()

# %%
data.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI          year         month  \
# count  21490.000000  11422.000000  24850.000000  29531.000000  29531.000000
# mean       8.700972      3.070128    166.463581   2017.887914      6.362771
# std       19.969164      6.323247    140.696585      1.533783      3.444773
# min        0.000000      0.000000     13.000000   2015.000000      1.000000
# 25%        0.600000      0.140000     81.000000   2017.000000      3.000000
# 50%        2.970000      0.980000    118.000000   2018.000000      6.000000
# 75%        9.150000      3.350000    208.000000   2019.000000      9.000000
# max      454.850000    170.370000   2049.000000   2020.000000     12.000000
#
#                 day
# count  29531.000000
# mean      15.667129
# std        8.901108
# min        1.000000
# 25%        8.000000
# 50%       16.000000
# 75%       23.000000
# max       31.000000

# %%
#Converting dtype of date column to datetime
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['year'] = data['Date'].apply(lambda x:x.year)
data['month'] = data['Date'].apply(lambda x:x.month)
data['day'] = data['Date'].apply(lambda x:x.day)


data.head()
# Out:
#      State       City station                  StationName  Status       Date  \
# 0  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-01-01
# 1  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-02-01
# 2  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-03-01
# 3  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-04-01
# 4  Gujarat  Ahmedabad   GJ001  Maninagar, Ahmedabad - GPCB  Active 2015-05-01
#
#    PM2.5  PM10     NO    NO2  ...    SO2      O3  Benzene  Toluene  Xylene  \
# 0    NaN   NaN   0.92  18.22  ...  27.64  133.36     0.00     0.02    0.00
# 1    NaN   NaN   0.97  15.69  ...  24.55   34.06     3.68     5.50    3.77
# 2    NaN   NaN  17.40  19.30  ...  29.07   30.70     6.80    16.40    2.25
# 3    NaN   NaN   1.70  18.48  ...  18.59   36.08     4.43    10.14    1.00
# 4    NaN   NaN  22.10  21.42  ...  39.33   39.31     7.01    18.89    2.78
#
#    AQI  AQI_Bucket  year  month day
# 0  NaN         NaN  2015      1   1
# 1  NaN         NaN  2015      2   1
# 2  NaN         NaN  2015      3   1
# 3  NaN         NaN  2015      4   1
# 4  NaN         NaN  2015      5   1
#
# [5 rows x 23 columns]

# %%
data['month_sin'] = np.sin(data['month']*(2.*np.pi/12))
data['month_cos'] = np.cos(data['month']*(2.*np.pi/12))

# %%
data=data.drop(['Date','station','StationName','Status'],axis=1)

# %%
data.columns
# Out:
# Index(['State', 'City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket',
#        'year', 'month', 'day', 'month_sin', 'month_cos'],
#       dtype='object')

# %%
data.head()
# Out:
#      State       City  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Gujarat  Ahmedabad    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Gujarat  Ahmedabad    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Gujarat  Ahmedabad    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Gujarat  Ahmedabad    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Gujarat  Ahmedabad    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#    ...  Benzene  Toluene  Xylene  AQI  AQI_Bucket  year  month  day  \
# 0  ...     0.00     0.02    0.00  NaN         NaN  2015      1    1
# 1  ...     3.68     5.50    3.77  NaN         NaN  2015      2    1
# 2  ...     6.80    16.40    2.25  NaN         NaN  2015      3    1
# 3  ...     4.43    10.14    1.00  NaN         NaN  2015      4    1
# 4  ...     7.01    18.89    2.78  NaN         NaN  2015      5    1
#
#    month_sin     month_cos
# 0   0.500000  8.660254e-01
# 1   0.866025  5.000000e-01
# 2   1.000000  6.123234e-17
# 3   0.866025 -5.000000e-01
# 4   0.500000 -8.660254e-01
#
# [5 rows x 21 columns]

# %% [raw]
# filling nan values present in the pollutants with mean city wise

# %%
data.iloc[:,2:14]=data.groupby('City').transform(lambda x:x.fillna(x.mean()))

# %%
data.head()
# Out:
#      State       City      PM2.5        PM10     NO    NO2    NOx  NH3     CO  \
# 0  Gujarat  Ahmedabad  67.854497  114.584029   0.92  18.22  17.15  NaN   0.92
# 1  Gujarat  Ahmedabad  67.854497  114.584029   0.97  15.69  16.46  NaN   0.97
# 2  Gujarat  Ahmedabad  67.854497  114.584029  17.40  19.30  29.70  NaN  17.40
# 3  Gujarat  Ahmedabad  67.854497  114.584029   1.70  18.48  17.97  NaN   1.70
# 4  Gujarat  Ahmedabad  67.854497  114.584029  22.10  21.42  37.76  NaN  22.10
#
#      SO2  ...  Benzene  Toluene  Xylene  AQI  AQI_Bucket  year  month  day  \
# 0  27.64  ...     0.00     0.02    0.00  NaN         NaN  2015      1    1
# 1  24.55  ...     3.68     5.50    3.77  NaN         NaN  2015      2    1
# 2  29.07  ...     6.80    16.40    2.25  NaN         NaN  2015      3    1
# 3  18.59  ...     4.43    10.14    1.00  NaN         NaN  2015      4    1
# 4  39.33  ...     7.01    18.89    2.78  NaN         NaN  2015      5    1
#
#    month_sin     month_cos
# 0   0.500000  8.660254e-01
# 1   0.866025  5.000000e-01
# 2   1.000000  6.123234e-17
# 3   0.866025 -5.000000e-01
# 4   0.500000 -8.660254e-01
#
# [5 rows x 21 columns]

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.loc[:,2:14]=data.fillna(data.mean())

# %%
data.head()
# Out:
#      State       City      PM2.5        PM10     NO    NO2    NOx        NH3  \
# 0  Gujarat  Ahmedabad  67.854497  114.584029   0.92  18.22  17.15  23.024137
# 1  Gujarat  Ahmedabad  67.854497  114.584029   0.97  15.69  16.46  23.024137
# 2  Gujarat  Ahmedabad  67.854497  114.584029  17.40  19.30  29.70  23.024137
# 3  Gujarat  Ahmedabad  67.854497  114.584029   1.70  18.48  17.97  23.024137
# 4  Gujarat  Ahmedabad  67.854497  114.584029  22.10  21.42  37.76  23.024137
#
#       CO    SO2  ...  Benzene  Toluene  Xylene  AQI  AQI_Bucket  year  month  \
# 0   0.92  27.64  ...     0.00     0.02    0.00  NaN         NaN  2015      1
# 1   0.97  24.55  ...     3.68     5.50    3.77  NaN         NaN  2015      2
# 2  17.40  29.07  ...     6.80    16.40    2.25  NaN         NaN  2015      3
# 3   1.70  18.59  ...     4.43    10.14    1.00  NaN         NaN  2015      4
# 4  22.10  39.33  ...     7.01    18.89    2.78  NaN         NaN  2015      5
#
#    day  month_sin     month_cos
# 0    1   0.500000  8.660254e-01
# 1    1   0.866025  5.000000e-01
# 2    1   1.000000  6.123234e-17
# 3    1   0.866025 -5.000000e-01
# 4    1   0.500000 -8.660254e-01
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#                 State           City  PM2.5   PM10    NO    NO2    NOx    NH3  \
# 29526  Andhra Pradesh  Visakhapatnam  15.02  50.94  7.68  25.06  19.54  12.47
# 29527  Andhra Pradesh  Visakhapatnam  24.38  74.09  3.42  26.06  16.53  11.99
# 29528  Andhra Pradesh  Visakhapatnam  22.91  65.73  3.45  29.53  18.33  10.71
# 29529  Andhra Pradesh  Visakhapatnam  16.64  49.97  4.05  29.26  18.80  10.03
# 29530  Andhra Pradesh  Visakhapatnam  15.00  66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2  ...   Benzene    Toluene    Xylene   AQI    AQI_Bucket  \
# 29526  0.47   8.55  ...  2.240000  12.070000  0.730000  41.0          Good
# 29527  0.52  12.72  ...  0.740000   2.210000  0.380000  70.0  Satisfactory
# 29528  0.48   8.42  ...  0.010000   0.010000  0.000000  68.0  Satisfactory
# 29529  0.52   9.84  ...  0.000000   0.000000  0.000000  54.0  Satisfactory
# 29530  0.59   2.10  ...  3.891348   8.350983  2.790456  50.0          Good
#
#        year  month  day     month_sin  month_cos
# 29526  2020      6   27  1.224647e-16  -1.000000
# 29527  2020      6   28  1.224647e-16  -1.000000
# 29528  2020      6   29  1.224647e-16  -1.000000
# 29529  2020      6   30  1.224647e-16  -1.000000
# 29530  2020      1    7  5.000000e-01   0.866025
#
# [5 rows x 21 columns]

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [raw]
# The AQI Calculation uses 7 measures:PM2.5,PM10,SO2,NOx,NH3,CO and O3

# %%
#PM10 sub_index calculation
def get_PM10_subindex(x):
    if x<=50:
        return x
    elif x>50 and x<=100:
        return x
    elif x>100 and x<=250:
        return 100+(x-100)*100/150
    elif x>250 and x<=350:
        return 200+(x-250)
    elif x>350 and x<=430:
        return 300+(x-350)*100/80
    elif x>430:
        return 400+(x-430)*100/80
    else:
        return 0
data['PM10_subindex']=data['PM10'].astype(int).apply(lambda x:get_PM10_subindex(x))
d1=data[['PM10','PM10_subindex']]
d1.head()
# Out:
#          PM10  PM10_subindex
# 0  114.584029     109.333333
# 1  114.584029     109.333333
# 2  114.584029     109.333333
# 3  114.584029     109.333333
# 4  114.584029     109.333333

# %%
def get_PM25_subindex(x):
    if x<=30:
        return x*50/30
    elif x>30 and x<=60:
        return 50+(x-30)*50/30
    elif x>60 and x<=90:
        return 100+(x-60)*100/30
    elif x>90 and x<=120:
        return 200+(x-90)*100/30
    elif x>120 and x<=250:
        return 300+(x-120)*100/130
    elif x>250:
        return 400+(x-250)*100/130
    else:
        return 0
data['PM2.5_subindex']=data['PM2.5'].astype(int).apply(lambda x:get_PM25_subindex(x))

# %%
def get_SO2_subindex(x):
    if x<=40:
        return x*50/40
    elif x>40 and x<=80:
        return 50+(x-40)*50/40
    elif x>80 and x<=380:
        return 100+(x-80)*100/300
    elif x>380 and x<=800:
        return 200+(x-380)*100/420
    elif x>800 and x<=1600:
        return 300+(x-800)*100/800
    elif x>1600:
        return 400+(x-1600)*100/800
    else:
        return 0
data['SO2_subindex']=data['SO2'].astype(int).apply(lambda x:get_SO2_subindex(x))

# %%
def get_NOx_subindex(x):
    if x<=40:
        return x*50/40
    elif x>40 and x<=80:
        return 50+(x-40)*50/40
    elif x>80 and x<=180:
        return 100+(x-80)*100/100
    elif x>180 and x<=280:
        return 200+(x-180)*100/100
    elif x>280 and x<=400:
        return 300+(x-280)*100/120
    elif x>400:
        return 400+(x-400)*100/120
    else:
        return 0
data['NOx_subindex']=data['NOx'].astype(int).apply(lambda x:get_NOx_subindex(x))

# %%
def get_NH3_subindex(x):
    if x<=200:
        return x*50/200
    elif x>200 and x<=400:
        return 50+(x-200)*50/200
    elif x>400 and x<=800:
        return 100+(x-400)*100/400
    elif x>800 and x<=1200:
        return 200+(x-800)*100/400
    elif x>1200 and x<=1800:
        return 300+(x-1200)*100/600
    elif x>1800:
        return 400+(x-1800)*100/600
    else:
        return 0
data['NH3_subindex']=data['NH3'].astype(int).apply(lambda x:get_NH3_subindex(x))

# %%
def get_CO_subindex(x):
    if x<=1:
        return x*50/1
    elif x>1 and x<=2:
        return 50+(x-1)*50/1
    elif x>2 and x<=10:
        return 100+(x-2)*100/8
    elif x>10 and x<=17:
        return 200+(x-10)*100/7
    elif x>17 and x<=34:
        return 300+(x-17)*100/17
    elif x>34:
        return 400+(x-34)*100/17
    else:
        return 0
data['CO_subindex']=data['CO'].astype(int).apply(lambda x:get_CO_subindex(x))

# %%
def get_O3_subindex(x):
    if x<=50:
        return x*50/50
    elif x>50 and x<=100:
        return 50+(x-50)*50/50
    elif x>100 and x<=168:
        return 100+(x-100)*100/68
    elif x>168 and x<=208:
        return 200+(x-168)*100/40
    elif x>208 and x<=748:
        return 300+(x-208)*100/539
    elif x>748:
        return 400+(x-400)*100/539
    else:
        return 0
data['O3_subindex']=data['O3'].astype(int).apply(lambda x:get_O3_subindex(x))

# %%
data['AQI']=data['AQI'].fillna(round(data[['PM2.5_subindex','PM10_subindex','SO2_subindex','NOx_subindex','NH3_subindex','CO_subindex','O3_subindex']].max(axis=1)))

# %%
data.head()
# Out:
#      State       City      PM2.5        PM10     NO    NO2    NOx        NH3  \
# 0  Gujarat  Ahmedabad  67.854497  114.584029   0.92  18.22  17.15  23.024137
# 1  Gujarat  Ahmedabad  67.854497  114.584029   0.97  15.69  16.46  23.024137
# 2  Gujarat  Ahmedabad  67.854497  114.584029  17.40  19.30  29.70  23.024137
# 3  Gujarat  Ahmedabad  67.854497  114.584029   1.70  18.48  17.97  23.024137
# 4  Gujarat  Ahmedabad  67.854497  114.584029  22.10  21.42  37.76  23.024137
#
#       CO    SO2  ...  day  month_sin     month_cos  PM10_subindex  \
# 0   0.92  27.64  ...    1   0.500000  8.660254e-01     109.333333
# 1   0.97  24.55  ...    1   0.866025  5.000000e-01     109.333333
# 2  17.40  29.07  ...    1   1.000000  6.123234e-17     109.333333
# 3   1.70  18.59  ...    1   0.866025 -5.000000e-01     109.333333
# 4  22.10  39.33  ...    1   0.500000 -8.660254e-01     109.333333
#
#    PM2.5_subindex SO2_subindex  NOx_subindex  NH3_subindex  CO_subindex  \
# 0      123.333333        33.75         21.25          5.75     0.000000
# 1      123.333333        30.00         20.00          5.75     0.000000
# 2      123.333333        36.25         36.25          5.75   300.000000
# 3      123.333333        22.50         21.25          5.75    50.000000
# 4      123.333333        48.75         46.25          5.75   329.411765
#
#    O3_subindex
# 0   148.529412
# 1    34.000000
# 2    30.000000
# 3    36.000000
# 4    39.000000
#
# [5 rows x 28 columns]

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
## AQI bucketing
def get_AQI_bucket(x):
    if x <= 50:
        return "Good"
    elif x > 50 and x <= 100:
        return "Satisfactory"
    elif x > 100 and x <= 200:
        return "Moderate"
    elif x > 200 and x <= 300:
        return "Poor"
    elif x > 300 and x <= 400:
        return "Very Poor"
    elif x > 400:
        return "Severe"
    else:
        return '0'
    
data["AQI_Bucket"] = data["AQI_Bucket"].fillna(data["AQI"].apply(lambda x: get_AQI_bucket(x)))

# %%
data.head()
# Out:
#      State       City      PM2.5        PM10     NO    NO2    NOx        NH3  \
# 0  Gujarat  Ahmedabad  67.854497  114.584029   0.92  18.22  17.15  23.024137
# 1  Gujarat  Ahmedabad  67.854497  114.584029   0.97  15.69  16.46  23.024137
# 2  Gujarat  Ahmedabad  67.854497  114.584029  17.40  19.30  29.70  23.024137
# 3  Gujarat  Ahmedabad  67.854497  114.584029   1.70  18.48  17.97  23.024137
# 4  Gujarat  Ahmedabad  67.854497  114.584029  22.10  21.42  37.76  23.024137
#
#       CO    SO2  ...  day  month_sin     month_cos  PM10_subindex  \
# 0   0.92  27.64  ...    1   0.500000  8.660254e-01     109.333333
# 1   0.97  24.55  ...    1   0.866025  5.000000e-01     109.333333
# 2  17.40  29.07  ...    1   1.000000  6.123234e-17     109.333333
# 3   1.70  18.59  ...    1   0.866025 -5.000000e-01     109.333333
# 4  22.10  39.33  ...    1   0.500000 -8.660254e-01     109.333333
#
#    PM2.5_subindex SO2_subindex  NOx_subindex  NH3_subindex  CO_subindex  \
# 0      123.333333        33.75         21.25          5.75     0.000000
# 1      123.333333        30.00         20.00          5.75     0.000000
# 2      123.333333        36.25         36.25          5.75   300.000000
# 3      123.333333        22.50         21.25          5.75    50.000000
# 4      123.333333        48.75         46.25          5.75   329.411765
#
#    O3_subindex
# 0   148.529412
# 1    34.000000
# 2    30.000000
# 3    36.000000
# 4    39.000000
#
# [5 rows x 28 columns]

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
#Finding outliers
graph=data.select_dtypes(include=['float64','int64'])
graph.boxplot(figsize=(20,15))
plt.show()

# %%
#Outliers count in each column
#data=data.drop(['Date'],axis=1)
Q1=data.quantile(.25)
Q3=data.quantile(.75)
IQR=Q3-Q1
print(((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR))).sum())
# Out:
# AQI               1289
# AQI_Bucket           0
# Benzene           1639
# CO                2922
# CO_subindex       2320
# City                 0
# NH3               2118
# NH3_subindex      1979
# NO                2021
# NO2               1260
# NOx               1855
# NOx_subindex      1820
# O3                1059
# O3_subindex        939
# PM10              1980
# PM10_subindex     1500
# PM2.5             2405
# PM2.5_subindex    2920
# SO2               3443
# SO2_subindex      3636
# State                0
# Toluene           3246
# Xylene            1951
# day                  0
# month                0
# month_cos            0
# month_sin            0
# year                 0
# dtype: int64

# %%
data.columns
# Out:
# Index(['State', 'City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket',
#        'year', 'month', 'day', 'month_sin', 'month_cos', 'PM10_subindex',
#        'PM2.5_subindex', 'SO2_subindex', 'NOx_subindex', 'NH3_subindex',
#        'CO_subindex', 'O3_subindex'],
#       dtype='object')

# %%
for features in ['Benzene','CO','NH3','NO','NO2','PM2.5','PM10','NOx','O3','SO2','Toluene','Xylene','AQI','CO_subindex','NH3_subindex','NOx_subindex','O3_subindex','PM10_subindex','PM2.5_subindex','SO2_subindex']:
         OF_Q1=data[features].quantile(0.25)
         OF_Q2=data[features].quantile(0.50)
         OF_Q3=data[features].quantile(0.75)
         OF_IQR=OF_Q3-OF_Q1
         OF_low_limit=OF_Q1-1.5*OF_IQR
         OF_up_limit=OF_Q3+1.5*OF_IQR
         OF_outlier=data[(data[features]<OF_low_limit)|(data[features]>OF_low_limit)]
         data[features]=data[features].clip(OF_up_limit,OF_low_limit)

# %%
Q1=data.quantile(.25)
Q3=data.quantile(.75)
IQR=Q3-Q1
print(((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR))).sum())
# Out:
# AQI               0
# AQI_Bucket        0
# Benzene           0
# CO                0
# CO_subindex       0
# City              0
# NH3               0
# NH3_subindex      0
# NO                0
# NO2               0
# NOx               0
# NOx_subindex      0
# O3                0
# O3_subindex       0
# PM10              0
# PM10_subindex     0
# PM2.5             0
# PM2.5_subindex    0
# SO2               0
# SO2_subindex      0
# State             0
# Toluene           0
# Xylene            0
# day               0
# month             0
# month_cos         0
# month_sin         0
# year              0
# dtype: int64

# %%
graph=data.select_dtypes(include=['float64','int64'])
graph.boxplot(figsize=(20,15))
plt.show()

# %%
data.columns
# Out:
# Index(['State', 'City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket',
#        'year', 'month', 'day', 'month_sin', 'month_cos', 'PM10_subindex',
#        'PM2.5_subindex', 'SO2_subindex', 'NOx_subindex', 'NH3_subindex',
#        'CO_subindex', 'O3_subindex'],
#       dtype='object')

# %% [markdown]
# # Encoding

# %%
data['State'].replace({'Gujarat':0, 'Mizoram':1, 'Andhra Pradesh':2, 'Punjab':3, 'Karnataka':4,\
                       'Madhya Pradesh':5, 'Odisha':6, 'Chandigarh':7, 'Tamilnadu':8, 'Delhi':9,\
                       'Kerala':10, 'kerala':10,'Haryana':11, 'Assam':12, 'Telengana':13, 'Rajasthan':14,\
                       'Jharkhand':15, 'West Bengal':16, 'Uttar Pradesh':17,'Maharashtra':18,\
                       'Bihar':19, 'Meghalaya':20},inplace=True)

# %%
data['City'].replace({'Ahmedabad':0, 'Aizawl':1, 'Amaravati':2, 'Amritsar':3, 'Bengaluru':4,\
                      'Bhopal':5, 'Brajrajnagar':6, 'Chandigarh':7, 'Chennai':8, 'Coimbatore':9,\
                      'Delhi':10, 'Ernakulam':11, 'Gurugram':12, 'Guwahati':13, 'Hyderabad':14,\
                      'Jaipur':15, 'Jorapokhar':16, 'Kochi':17, 'Kolkata':18, 'Lucknow':19, 'Mumbai':20,\
                      'Patna':21, 'Shillong':22, 'Talcher':23,'Thiruvananthapuram':24,'Visakhapatnam':25},inplace=True)

# %%
data=data.drop(['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene'],axis=1)

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=.1,vmax=.9,annot=True,linewidth=.2)
# Out:
# <AxesSubplot:>

# %%
data['AQI_Bucket'].value_counts()
# Out:
# Moderate        10344
# Satisfactory     9800
# Very Poor        3338
# Poor             3121
# Good             1539
# Severe           1389
# Name: AQI_Bucket, dtype: int64

# %%
data['month'].replace({1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',\
                           9:'September',10:'October',11:'November',12:'December'},inplace=True)

# %%
data
# Out:
#        State  City    AQI    AQI_Bucket  year     month  day     month_sin  \
# 0          0     0  149.0      Moderate  2015   January    1  5.000000e-01
# 1          0     0  123.0      Moderate  2015  February    1  8.660254e-01
# 2          0     0  300.0          Poor  2015     March    1  1.000000e+00
# 3          0     0  123.0      Moderate  2015     April    1  8.660254e-01
# 4          0     0  329.0     Very Poor  2015       May    1  5.000000e-01
# ...      ...   ...    ...           ...   ...       ...  ...           ...
# 29526      2    25   41.0          Good  2020      June   27  1.224647e-16
# 29527      2    25   70.0  Satisfactory  2020      June   28  1.224647e-16
# 29528      2    25   68.0  Satisfactory  2020      June   29  1.224647e-16
# 29529      2    25   54.0  Satisfactory  2020      June   30  1.224647e-16
# 29530      2    25   50.0          Good  2020   January    7  5.000000e-01
#
#           month_cos  PM10_subindex  PM2.5_subindex  SO2_subindex  \
# 0      8.660254e-01     109.333333      123.333333        33.750
# 1      5.000000e-01     109.333333      123.333333        30.000
# 2      6.123234e-17     109.333333      123.333333        35.625
# 3     -5.000000e-01     109.333333      123.333333        22.500
# 4     -8.660254e-01     109.333333      123.333333        35.625
# ...             ...            ...             ...           ...
# 29526 -1.000000e+00      50.000000       25.000000        10.000
# 29527 -1.000000e+00      74.000000       40.000000        15.000
# 29528 -1.000000e+00      65.000000       36.666667        10.000
# 29529 -1.000000e+00      49.000000       26.666667        11.250
# 29530  8.660254e-01      66.000000       25.000000         2.500
#
#        NOx_subindex  NH3_subindex  CO_subindex  O3_subindex
# 0             21.25          5.75          0.0         79.0
# 1             20.00          5.75          0.0         34.0
# 2             36.25          5.75        125.0         30.0
# 3             21.25          5.75         50.0         36.0
# 4             46.25          5.75        125.0         39.0
# ...             ...           ...          ...          ...
# 29526         23.75          3.00          0.0         23.0
# 29527         20.00          2.75          0.0         30.0
# 29528         22.50          2.50          0.0         30.0
# 29529         22.50          2.50          0.0         28.0
# 29530         17.50          1.25          0.0         17.0
#
# [29531 rows x 16 columns]

# %% [markdown]
# # Feature Reduction

# %%
data['PM']=data['PM10_subindex']+data['PM2.5_subindex']
data['Ni']=data['NOx_subindex']+data['NH3_subindex']
data
# Out:
#        State  City    AQI    AQI_Bucket  year     month  day     month_sin  \
# 0          0     0  149.0      Moderate  2015   January    1  5.000000e-01
# 1          0     0  123.0      Moderate  2015  February    1  8.660254e-01
# 2          0     0  300.0          Poor  2015     March    1  1.000000e+00
# 3          0     0  123.0      Moderate  2015     April    1  8.660254e-01
# 4          0     0  329.0     Very Poor  2015       May    1  5.000000e-01
# ...      ...   ...    ...           ...   ...       ...  ...           ...
# 29526      2    25   41.0          Good  2020      June   27  1.224647e-16
# 29527      2    25   70.0  Satisfactory  2020      June   28  1.224647e-16
# 29528      2    25   68.0  Satisfactory  2020      June   29  1.224647e-16
# 29529      2    25   54.0  Satisfactory  2020      June   30  1.224647e-16
# 29530      2    25   50.0          Good  2020   January    7  5.000000e-01
#
#           month_cos  PM10_subindex  PM2.5_subindex  SO2_subindex  \
# 0      8.660254e-01     109.333333      123.333333        33.750
# 1      5.000000e-01     109.333333      123.333333        30.000
# 2      6.123234e-17     109.333333      123.333333        35.625
# 3     -5.000000e-01     109.333333      123.333333        22.500
# 4     -8.660254e-01     109.333333      123.333333        35.625
# ...             ...            ...             ...           ...
# 29526 -1.000000e+00      50.000000       25.000000        10.000
# 29527 -1.000000e+00      74.000000       40.000000        15.000
# 29528 -1.000000e+00      65.000000       36.666667        10.000
# 29529 -1.000000e+00      49.000000       26.666667        11.250
# 29530  8.660254e-01      66.000000       25.000000         2.500
#
#        NOx_subindex  NH3_subindex  CO_subindex  O3_subindex          PM     Ni
# 0             21.25          5.75          0.0         79.0  232.666667  27.00
# 1             20.00          5.75          0.0         34.0  232.666667  25.75
# 2             36.25          5.75        125.0         30.0  232.666667  42.00
# 3             21.25          5.75         50.0         36.0  232.666667  27.00
# 4             46.25          5.75        125.0         39.0  232.666667  52.00
# ...             ...           ...          ...          ...         ...    ...
# 29526         23.75          3.00          0.0         23.0   75.000000  26.75
# 29527         20.00          2.75          0.0         30.0  114.000000  22.75
# 29528         22.50          2.50          0.0         30.0  101.666667  25.00
# 29529         22.50          2.50          0.0         28.0   75.666667  25.00
# 29530         17.50          1.25          0.0         17.0   91.000000  18.75
#
# [29531 rows x 18 columns]

# %%
#Feature Engineering
#data['BTX'] = data["Benzene"]+data["Toluene"]+data["Xylene"]
#data['PM'] =data["PM2.5"]+data["PM10"]
y=data['AQI']
X = data[['State','City','year', 'PM','CO_subindex','O3_subindex','Ni','SO2_subindex']]

# %% [raw]
# from statsmodels.stats.outliers_influence import variance_inflation_factor
#
# vif_info = pd.DataFrame()
# vif_info['VIF'] = [variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
# vif_info['Colums'] = X.columns
# vif_info.sort_values('VIF', ascending = False)

# %%
X.head()
# Out:
#    State  City  year          PM  CO_subindex  O3_subindex     Ni  \
# 0      0     0  2015  232.666667          0.0         79.0  27.00
# 1      0     0  2015  232.666667          0.0         34.0  25.75
# 2      0     0  2015  232.666667        125.0         30.0  42.00
# 3      0     0  2015  232.666667         50.0         36.0  27.00
# 4      0     0  2015  232.666667        125.0         39.0  52.00
#
#    SO2_subindex
# 0        33.750
# 1        30.000
# 2        35.625
# 3        22.500
# 4        35.625

# %% [markdown]
# # splitting of data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
pip install nestedhyperboost
# Out:
# Requirement already satisfied: nestedhyperboost in c:\users\chinnu\anaconda3\lib\site-packages (0.0.3)
# Requirement already satisfied: hyperopt in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (0.2.7)
# Requirement already satisfied: catboost in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (1.0.6)
# Requirement already satisfied: numpy in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (1.20.3)
# Requirement already satisfied: lightgbm in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (3.3.2)
# Requirement already satisfied: sklearn in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (0.0)
# Requirement already satisfied: xgboost in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (1.6.1)
# Requirement already satisfied: pandas in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (1.3.4)
# Requirement already satisfied: matplotlib in c:\users\chinnu\anaconda3\lib\site-packages (from nestedhyperboost) (3.4.3)
# Requirement already satisfied: plotly in c:\users\chinnu\anaconda3\lib\site-packages (from catboost->nestedhyperboost) (5.9.0)
# Requirement already satisfied: six in c:\users\chinnu\anaconda3\lib\site-packages (from catboost->nestedhyperboost) (1.16.0)
# Requirement already satisfied: scipy in c:\users\chinnu\anaconda3\lib\site-packages (from catboost->nestedhyperboost) (1.7.1)
# Requirement already satisfied: graphviz in c:\users\chinnu\anaconda3\lib\site-packages (from catboost->nestedhyperboost) (0.20)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\chinnu\anaconda3\lib\site-packages (from pandas->nestedhyperboost) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\chinnu\anaconda3\lib\site-packages (from pandas->nestedhyperboost) (2021.3)
# Requirement already satisfied: cloudpickle in c:\users\chinnu\anaconda3\lib\site-packages (from hyperopt->nestedhyperboost) (2.0.0)
# Requirement already satisfied: future in c:\users\chinnu\anaconda3\lib\site-packages (from hyperopt->nestedhyperboost) (0.18.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\chinnu\anaconda3\lib\site-packages (from hyperopt->nestedhyperboost) (2.6.3)
# Requirement already satisfied: tqdm in c:\users\chinnu\anaconda3\lib\site-packages (from hyperopt->nestedhyperboost) (4.62.3)
# Requirement already satisfied: py4j in c:\users\chinnu\anaconda3\lib\site-packages (from hyperopt->nestedhyperboost) (0.10.9.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\chinnu\anaconda3\lib\site-packages (from lightgbm->nestedhyperboost) (0.24.2)
# Requirement already satisfied: wheel in c:\users\chinnu\anaconda3\lib\site-packages (from lightgbm->nestedhyperboost) (0.37.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chinnu\anaconda3\lib\site-packages (from matplotlib->nestedhyperboost) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\chinnu\anaconda3\lib\site-packages (from matplotlib->nestedhyperboost) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chinnu\anaconda3\lib\site-packages (from matplotlib->nestedhyperboost) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chinnu\anaconda3\lib\site-packages (from matplotlib->nestedhyperboost) (8.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chinnu\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm->nestedhyperboost) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\chinnu\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm->nestedhyperboost) (1.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\chinnu\anaconda3\lib\site-packages (from plotly->catboost->nestedhyperboost) (8.0.1)
# Requirement already satisfied: colorama in c:\users\chinnu\anaconda3\lib\site-packages (from tqdm->hyperopt->nestedhyperboost) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor,XGBRFRegressor
from lightgbm import LGBMRegressor

# %%
models = {
    'Linear Regression(Ridge)' : Ridge(),
    '          Neural Network' : MLPRegressor(),
    '           Random Forest' : RandomForestRegressor(),
    '                Catboost' : CatBoostRegressor(verbose=0),
    '       XGBoost Regressor' : XGBRegressor(),
    '    XGBoost RF Regressor' : XGBRFRegressor(),
    'Linear Regression(lasso)' : Lasso(),
    '       Linear Regression' : LinearRegression(),
    ' Light Gradient Boosting' : LGBMRegressor()
}
for name, model in models.items():
    model.fit(X_train, y_train)
    print(name + ' trained.')
# Out:
# Linear Regression(Ridge) trained.
#           Neural Network trained.
#            Random Forest trained.
#                 Catboost trained.
#        XGBoost Regressor trained.
#     XGBoost RF Regressor trained.
# Linear Regression(lasso) trained.
#        Linear Regression trained.
#  Light Gradient Boosting trained.

# %%
def get_rmse(y_true,y_pred):
    rmse = np.sqrt(np.mean((y_test-y_pred)**2))
    return rmse

def get_r2(y_true,y_pred):
    r2 = 1 - (np.sum((y_test - y_pred)**2) / np.sum((y_test - y_test.mean())**2))
    return r2

# %%
for name, model in models.items():
    y_pred = model.predict(X_test)
    rmse = get_rmse(y_test, y_pred)
    print(name + ' RMSE: {:.2f}'.format(rmse))
# Out:
# Linear Regression(Ridge) RMSE: 46.57
#           Neural Network RMSE: 38.47
#            Random Forest RMSE: 31.23
#                 Catboost RMSE: 29.91
#        XGBoost Regressor RMSE: 30.90
#     XGBoost RF Regressor RMSE: 33.47
# Linear Regression(lasso) RMSE: 46.58
#        Linear Regression RMSE: 46.57
#  Light Gradient Boosting RMSE: 30.22

# %%
for name, model in models.items():
    y_pred = model.predict(X_test)
    r2 = get_r2(y_test, y_pred)
    print(name + ' R^2: {:.5f}'.format(r2))
# Out:
# Linear Regression(Ridge) R^2: 0.79830
#           Neural Network R^2: 0.86238
#            Random Forest R^2: 0.90933
#                 Catboost R^2: 0.91683
#        XGBoost Regressor R^2: 0.91123
#     XGBoost RF Regressor R^2: 0.89582
# Linear Regression(lasso) R^2: 0.79819
#        Linear Regression R^2: 0.79830
#  Light Gradient Boosting R^2: 0.91509

# %%
X.tail()
# Out:
#        State  City  year          PM  CO_subindex  O3_subindex     Ni  \
# 29526      2    25  2020   75.000000          0.0         23.0  26.75
# 29527      2    25  2020  114.000000          0.0         30.0  22.75
# 29528      2    25  2020  101.666667          0.0         30.0  25.00
# 29529      2    25  2020   75.666667          0.0         28.0  25.00
# 29530      2    25  2020   91.000000          0.0         17.0  18.75
#
#        SO2_subindex
# 29526         10.00
# 29527         15.00
# 29528         10.00
# 29529         11.25
# 29530          2.50

# %%
#LGBMRegressor

# %%
lgbm = LGBMRegressor()
lgbm.fit(X_train, y_train)
lgbm_pred = lgbm.predict(X_test)
mse(y_test, lgbm_pred, squared=False)
# Out:
# 30.217999423048852

# %%
from sklearn.metrics import r2_score
r_square = r2_score(y_test, lgbm_pred)
r_square
# Out:
# 0.9150853923563818

# %%
results = pd.DataFrame({'Model': [ 'Linear Regression(Ridge)','Neural Network','Random Forest','Catboost','XGBoost Regressor',' XGBoost RF Regressor', 
                                   'Linear Regression(lasso)',' Linear Regression','Light Gradient Boosting'], 
                        'Score': [ 0.79830,0.87776,0.90934,0.91683,0.91123,0.89582,0.79819, 0.79830,0.91509]})

                                  
                        

result_df = results.sort_values(by='Score', ascending=False)

result_df
# Out:
#                       Model    Score
# 3                  Catboost  0.91683
# 8   Light Gradient Boosting  0.91509
# 4         XGBoost Regressor  0.91123
# 2             Random Forest  0.90934
# 5      XGBoost RF Regressor  0.89582
# 1            Neural Network  0.87776
# 0  Linear Regression(Ridge)  0.79830
# 7         Linear Regression  0.79830
# 6  Linear Regression(lasso)  0.79819

# %%
plt.bar(result_df['Model'],result_df['Score'], color = 'maroon',width=.5)
plt.title('relation of mode with score')
plt.xlabel('Model')
plt.xticks(rotation=90)
plt.ylabel('Score')
plt.ylim(.5,1)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
lgbm = LGBMRegressor()
lgbm.fit(X_train, y_train)
lgbm_pred = lgbm.predict(X_test)
mse(y_test, lgbm_pred, squared=False)
# Out:
# 30.217999423048852

# %%
from sklearn.metrics import r2_score
r_square = r2_score(y_test, lgbm_pred)
r_square
# Out:
# 0.9150853923563818

# %% [markdown]
# # prediction

# %%
x_predict = [0,25,2020,91.000000,0.0,17.0,18.75,2.50]
import numpy as np
x_predict = np.array(x_predict).reshape(1,-1)

# %%
predicted_value = lgbm.predict(x_predict) 
print("Predicted value : ",predicted_value)
# Out:
# Predicted value :  [76.154462]

# %%
x_predict = [0,25,2025,100.000000,0.0,18.0,19.75,2.50]
import numpy as np
x_predict = np.array(x_predict).reshape(1,-1)

# %%
predicted_value = lgbm.predict(x_predict) 
print("Predicted value : ",predicted_value)
# Out:
# Predicted value :  [80.79210333]

# %% [raw]
# rf= RandomForestRegressor()
# #distribution of prediction probabilities
# threshold=.22
# y_pred_prob=rf.predict_proba(X_test)[:,1]
# y_pred=(y_pred_prob>threshold).astype(int)
# f1_score(y_test,y_pred)

# %% [raw]
# rfr= RandomForestRegressor()
# rfr.fit(X_train,y_train)

# %% [raw]
# rfr = RandomForestRegressor(max_depth=2, random_state=0)
#
# rfr.fit(X_train,y_train)

# %% [raw]
# y_pred=rfr.predict(X_test)
# f1_score(y_test,y_pred)

# %%
#hypertuning

# %%
#Grid search CV

# %% [raw]
# from sklearn.model_selection import GridSearchCV
# parameters={'n_estimators':[100,300,500],'max_depth':[1,3,5]}
# rfr=RandomForestRegressor()
# clf=GridSearchCV(rfr,parameters)
# clf.fit(X_train,y_train)

# %% [raw]
# clf.best_score_

# %% [raw]
# clf.best_params_

# %% [raw]
# model=RandomForestRegressor(max_depth= 5, n_estimators= 500)
# model.fit(X_train, y_train)
# rf_pred = model.predict(X_test)
# mse(y_test, rf_pred, squared=False)

# %% [raw]
# from sklearn.metrics import r2_score
# r_square = r2_score(y_test, rf_pred)
# r_square

# %%
#Random searchCV

# %% [raw]
# from sklearn.model_selection import RandomizedSearchCV
# param={'n_estimators':[100,300,500],'max_depth':[1,3,5]}
# rfr=RandomForestRegressor()
# rlf=RandomizedSearchCV(rfr,param,n_iter=5)
# rlf.fit(X_train,y_train)

# %% [raw]
# rlf.best_score_

# %% [raw]
# rlf.best_params_

# %% [raw]
# rfr=RandomForestRegressor(n_estimators= 300, max_depth= 5)
# rlf=RandomizedSearchCV(rfr,param,n_iter=5)
# rlf.fit(X_train, y_train)
# rlf_pred = model.predict(X_test)
# mse(y_test, rlf_pred, squared=False)

# %% [raw]
# from sklearn.metrics import r2_score
# r_square = r2_score(y_test, rlf_pred)
# r_square

# %%
#hyper tuning of Lgbm regressor

# %%
lgbm = LGBMRegressor()
lgbm.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': 'warn',
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
lgbm = LGBMRegressor(max_depth=-1, n_estimators= 100)
lgbm.fit(X_train, y_train)
lgbm_pred = lgbm.predict(X_test)
mse(y_test, lgbm_pred, squared=False)
# Out:
# 30.217999423048852

# %%
from sklearn.metrics import r2_score
r_square = r2_score(y_test, lgbm_pred)
r_square
# Out:
# 0.9150853923563818

# %%
#Knn

# %%
from sklearn.neighbors import KNeighborsRegressor
Knn=KNeighborsRegressor()
Knn.fit(X_train,y_train)
predictions = Knn.predict(X_test)

# %%
mse(y_test, predictions, squared=False)
# Out:
# 34.958093100670474

# %%
from sklearn.metrics import r2_score
r_square = r2_score(y_test, predictions)
r_square
# Out:
# 0.8863560136228188

# %% [raw]
# import catboost as cb
# model = cb.CatBoostRegressor(loss_function='RMSE')
# train_dataset = cb.Pool(X_train, y_train)
# test_dataset = cb.Pool(X_test, y_test)

# %% [raw]
# grid = {'iterations': [100, 150, 200],
#         'learning_rate': [0.03, 0.1],
#         'depth': [2, 4, 6, 8],
#         'l2_leaf_reg': [0.2, 0.5, 1, 3]}
#
# model.grid_search(grid,train_dataset)
# pred1 = model.predict(X_test)

# %% [raw]
# from sklearn.metrics import r2_score
# r_square = r2_score(y_test, pred1)
# r_square

# %% [raw]
# mse(y_test, pred1, squared=False)

# %%
data['State'].replace({ 0 : 'Gujarat', 1:'Mizoram',2: 'Andhra Pradesh', 3: 'Punjab', 4:'Karnataka',\
                        5:'Madhya Pradesh', 6:'Odisha',7: 'Chandigarh', 8:'Tamilnadu', 9:'Delhi',\
                        10:'Kerala',21:'kerala' ,11:'Haryana', 12:'Assam', 13:'Telengana',14: 'Rajasthan',\
                        15:'Jharkhand',16: 'West Bengal', 17:'Uttar Pradesh',18:'Maharashtra',\
                        19:'Bihar', 20:'Meghalaya'},inplace=True)

# %%
data['City'].replace({0:'Ahmedabad', 1:'Aizawl', 2:'Amaravati', 3:'Amritsar', 4:'Bengaluru',\
                      5:'Bhopal', 6:'Brajrajnagar', 7:'Chandigarh', 8:'Chennai', 9:'Coimbatore',\
                      10:'Delhi', 11:'Ernakulam', 12:'Gurugram', 13:'Guwahati', 14:'Hyderabad',\
                      15:'Jaipur', 16:'Jorapokhar',17: 'Kochi', 18:'Kolkata', 19:'Lucknow', 20:'Mumbai',\
                      21:'Patna', 22:'Shillong', 23:'Talcher',24:'Thiruvananthapuram',25:'Visakhapatnam'},inplace=True)

# %%
data
# Out:
#                 State           City    AQI    AQI_Bucket  year     month  \
# 0             Gujarat      Ahmedabad  149.0      Moderate  2015   January
# 1             Gujarat      Ahmedabad  123.0      Moderate  2015  February
# 2             Gujarat      Ahmedabad  300.0          Poor  2015     March
# 3             Gujarat      Ahmedabad  123.0      Moderate  2015     April
# 4             Gujarat      Ahmedabad  329.0     Very Poor  2015       May
# ...               ...            ...    ...           ...   ...       ...
# 29526  Andhra Pradesh  Visakhapatnam   41.0          Good  2020      June
# 29527  Andhra Pradesh  Visakhapatnam   70.0  Satisfactory  2020      June
# 29528  Andhra Pradesh  Visakhapatnam   68.0  Satisfactory  2020      June
# 29529  Andhra Pradesh  Visakhapatnam   54.0  Satisfactory  2020      June
# 29530  Andhra Pradesh  Visakhapatnam   50.0          Good  2020   January
#
#        day     month_sin     month_cos  PM10_subindex  PM2.5_subindex  \
# 0        1  5.000000e-01  8.660254e-01     109.333333      123.333333
# 1        1  8.660254e-01  5.000000e-01     109.333333      123.333333
# 2        1  1.000000e+00  6.123234e-17     109.333333      123.333333
# 3        1  8.660254e-01 -5.000000e-01     109.333333      123.333333
# 4        1  5.000000e-01 -8.660254e-01     109.333333      123.333333
# ...    ...           ...           ...            ...             ...
# 29526   27  1.224647e-16 -1.000000e+00      50.000000       25.000000
# 29527   28  1.224647e-16 -1.000000e+00      74.000000       40.000000
# 29528   29  1.224647e-16 -1.000000e+00      65.000000       36.666667
# 29529   30  1.224647e-16 -1.000000e+00      49.000000       26.666667
# 29530    7  5.000000e-01  8.660254e-01      66.000000       25.000000
#
#        SO2_subindex  NOx_subindex  NH3_subindex  CO_subindex  O3_subindex  \
# 0            33.750         21.25          5.75          0.0         79.0
# 1            30.000         20.00          5.75          0.0         34.0
# 2            35.625         36.25          5.75        125.0         30.0
# 3            22.500         21.25          5.75         50.0         36.0
# 4            35.625         46.25          5.75        125.0         39.0
# ...             ...           ...           ...          ...          ...
# 29526        10.000         23.75          3.00          0.0         23.0
# 29527        15.000         20.00          2.75          0.0         30.0
# 29528        10.000         22.50          2.50          0.0         30.0
# 29529        11.250         22.50          2.50          0.0         28.0
# 29530         2.500         17.50          1.25          0.0         17.0
#
#                PM     Ni
# 0      232.666667  27.00
# 1      232.666667  25.75
# 2      232.666667  42.00
# 3      232.666667  27.00
# 4      232.666667  52.00
# ...           ...    ...
# 29526   75.000000  26.75
# 29527  114.000000  22.75
# 29528  101.666667  25.00
# 29529   75.666667  25.00
# 29530   91.000000  18.75
#
# [29531 rows x 18 columns]

# %%
x_predict = [0,25,2020,91.000000,0.0,17.0,18.75,2.50]
import numpy as np
x_predict = np.array(x_predict).reshape(1,-1)

# %%
predicted_value = model.predict(x_predict) 
print("Predicted value : ",predicted_value)
# Out:
# Predicted value :  [76.154462]

# %%
x_predict = [0,25,2025,91.000000,0.0,17.0,19.75,3.50]
import numpy as np
x_predict = np.array(x_predict).reshape(1,-1)

# %%
predicted_value = model.predict(x_predict) 
print("Predicted value : ",predicted_value)
# Out:
# Predicted value :  [76.71235373]

# %%
import pickle

# %%
pickle.dump(model,open(r'C:\Users\Chinnu\Desktop\aqiprediction\model.pkl','wb'))

# %%
pickle.dump(data,open(r'C:\Users\Chinnu\Desktop\aqiprediction\data.pkl','wb'))
